# %%
import requests
from bs4 import BeautifulSoup
import json

characters = [
    'Wilson', 'Willow', 'Wolfgang', 'Wendy', 'WX-78', 'Wickerbottom', 'Woodie',
    'Wes', 'Maxwell', 'Wigfrid', 'Webber', 'Winona', 'Warly', 'Wortox',
    'Wormwood', 'Wurt', 'Walter', 'Wanda', 'Wonkey'
]

base_url = "https://dontstarve.fandom.com/wiki/{}/Don%27t_Starve_Together"

# Список для хранения данных о всех персонажах
all_characters_data = []

for character in characters:
    # Формируем URL для текущего персонажа
    url = base_url.format(character.replace(" ", "_"))

    # Отправляем GET-запрос к странице
    response = requests.get(url)

    # Проверяем успешность запроса
    if response.status_code == 200:
        # Создаем объект BeautifulSoup для парсинга HTML
        soup = BeautifulSoup(response.content, 'html.parser')

        # Извлекаем название персонажа
        title_element = soup.find('h1', class_='page-header__title')
        character_name = title_element.text.strip() if title_element else "Unknown"
        print(f"\nCharacter Name: {character_name}\n")

        # Словарь для хранения данных о текущем персонаже
        character_data = {
            "name": character_name,
            "info": {},
            "stats": {}
        }

        # Извлекаем инфобокс
        infobox = soup.find('aside', role='region', class_='portable-infobox')
        if infobox:
            print("--- Character Info ---")
            for section in infobox.find_all('div', class_='pi-item'):
                label = section.find('h3', class_='pi-data-label')
                value = section.find('div', class_='pi-data-value')

                if label and value:
                    label_text = label.text.strip()
                    value_text = value.text.strip()
                    character_data["info"][label_text] = value_text
                    print(f"{label_text}: {value_text}")
        else:
            print("Infobox not found.")

        # Извлекаем данные о здоровье, голоде и рассудке из таблицы
        stats_table = soup.find('tbody')
        if stats_table:
            print("\n--- Base Stats ---")
            for stat in stats_table.find_all('td', class_='pi-horizontal-group-item'):
                source = stat.get('data-source', '')
                value = stat.text.strip()
                if source == 'health dst':
                    character_data["stats"]["Health"] = value
                    print(f"Health: {value}")
                elif source == 'hunger dst':
                    character_data["stats"]["Hunger"] = value
                    print(f"Hunger: {value}")
                elif source == 'sanity dst':
                    character_data["stats"]["Sanity"] = value
                    print(f"Sanity: {value}")
        else:
            print("Stats table not found.")

        # Добавляем данные о персонаже в общий список
        all_characters_data.append(character_data)
    else:
        print(f"\nFailed to retrieve the page for {character}. Status code: {response.status_code}")

# Сохраняем все собранные данные в JSON-файл
with open("characters_data.json", "w", encoding="utf-8") as json_file:
    json.dump(all_characters_data, json_file, ensure_ascii=False, indent=4)

print("\nAll character data has been saved to 'characters_data.json'")
# Out:
# Character Name: Wilson (Don't Starve Together)
#
# --- Character Info ---
# Title: The Gentleman Scientist
# Birthday: April 23
# Motto: "I will conquer this world with the power of my MIND!"
# Curio Cabinet Bio: At heart Wilson is truly a man of science. It's not in his nature to resist the call of the unknown.
# Odds of Survival: Slim
# Perks & Quirks: Grows a magnificent beard
# Special Filter:
# Favorite Food:
# Code: "wilson"
#
# --- Base Stats ---
# Health: 150
# Hunger: 150
# Sanity: 200
#
# Character Name: Willow (Don't Starve Together)
#
# --- Character Info ---
# Title: The Firestarter
# Birthday: May 7
# Motto: "All will bathe in the prettiest of flames."
# Curio Cabinet Bio: Willow is a candid woman whose penchant for fire often gets her into more than a little trouble.
# Odds of Survival: Slim
# Perks & Quirks: Has a fondness for fire, but hates the coldProtected by her cuddly bear, BernieHas a reliable lighter
# Special Filter:
# Sanity Modifier: -1.1x and +1.1xup to +11/min per nearby
# Special Item(s):
# Starting Item(s):
# Favorite Food:
# Code: "willow"
#
# --- Base Stats ---
# Health: 150
# Hunger: 150
# Sanity: 120
#
# Character Name: Wolfgang (Don't Starve Together)
#
# --- Character Info ---
# Title: The Strongman
# Birthday: October 2
# Motto: "I am mighty! No one is mightier!"
# Curio Cabinet Bio: Wolfgang is an affable, musclebound giant with a heart plagued by a myriad of phobias.
# Odds of Survival: Grim
# Perks & Quirks: Needs to work out to become mightyBecomes wimpy over timeBurns a lot of caloriesIs afraid of monsters and the dark
# Special Filter:
# Damage Modifier: 0.75×, 1× or 2×
# Hunger Modifier: -0.75× to -1×
# Sanity Modifier: -1.25× to -1.1×
# Special Item(s):
# Starting Item(s):
# Favorite Food:
# Code: "wolfgang"
#
# --- Base Stats ---
# Health: 200
# Hunger: 200
# Sanity: 200
#
# Character Name: Wendy (Don't Starve Together)
#
# --- Character Info ---
# Title: The Bereaved
# Birthday: November 11
# Motto: "Abigail? Come back! I'm not done playing with you."
# Curio Cabinet Bio: Wendy is a morose young lady with a sisterly bond so powerful, it transcends death itself.
# Odds of Survival: Slim
# Perks & Quirks: Is haunted by her twin sisterFeels comfortable in the darkDabbles in EctoherbologyDoesn't hit very hard
# Special Filter:
# Damage Modifier: 0.75×
# Sanity Modifier: 0.75×
# Special Item(s):
# Starting Item(s):
# Favorite Food:
# Code: "wendy"
#
# --- Base Stats ---
# Health: 150
# Hunger: 150
# Sanity: 200
#
# Character Name: WX-78 (Don't Starve Together)
#
# --- Character Info ---
# Title: The Soulless Automaton
# Buildday: November 28
# Motto: "EMPATHY MODULE NOT RESPONDING"
# Curio Cabinet Bio: One might assume WX's callous nature hides a sensitive inner soul. One would assume incorrectly.
# Odds of Survival: Grim
# Perks & Quirks: Can upgrade with circuitsNot a picky eaterIs charged by lightning, but damaged by water
# Special Filter: WX-78
# Health Modifier: -3 to -9 when wet
# Hunger Modifier: -1× to -0.512×
# Speed Modifier: 1× to 1.5×
# Special Item(s):
# Starting Item(s):
# Favorite Food:
# Code: "wx78"
#
# --- Base Stats ---
# Health: 125
# Hunger: 125
# Sanity: 150
#
# Character Name: Wickerbottom (Don't Starve Together)
#
# --- Character Info ---
# Title: The Librarian
# Birthday: December 6
# Motto: "Shhhh! No talking!"
# Curio Cabinet Bio: A woman of curious mind and stern air, Wickerbottom thrives on the lifelong pursuit of knowledge.
# Odds of Survival: Grim
# Perks & Quirks: Knows many thingsSelf publishes booksSuffers from insomniaHas a delicate stomach
# Special Item(s):
# Starting Item(s): ×2
# Favorite Food:
# Code: "wickerbottom"
#
# --- Base Stats ---
# Health: 125
# Hunger: 150
# Sanity: 250
#
# Character Name: Woodie (Don't Starve Together)
#
# --- Character Info ---
# Beaverness: 100
# Special Item(s):
# Starting Item(s):
# Favorite Food:
# Code: "woodie"
#
# --- Base Stats ---
# Health: 150
# Hunger: 150
# Sanity: 200
#
# Character Name: Wes (Don't Starve Together)
#
# --- Character Info ---
# Damage Modifier: 0.75×
# Special Item(s):
# Starting Item(s):
# Favorite Food:
# Code: "wes"
#
# --- Base Stats ---
#
# Character Name: Maxwell (Don't Starve Together)
#
# --- Character Info ---
# Sanity Modifier: +6.67/min
# Special Item(s):
# Starting Item(s): ×6
# Favorite Food:
# Code: "waxwell"
#
# --- Base Stats ---
# Health: 75
# Hunger: 150
# Sanity: 200
#
# Character Name: Wigfrid (Don't Starve Together)
#
# --- Character Info ---
# Damage Modifier: 1.25× (caused) and 0.75× (taken)
# Special Item(s): (insight)
# Starting Item(s): ×4
# Favorite Food:
# Code: "wathgrithr"
#
# --- Base Stats ---
# Health: 200
# Hunger: 120
# Sanity: 120
#
# Character Name: Webber (Don't Starve Together)
#
# --- Character Info ---
# Special Item(s):
# Starting Item(s): ×2
# Favorite Food:
# Code: "webber"
#
# --- Base Stats ---
# Health: 175
# Hunger: 175
# Sanity: 100
#
# Character Name: Winona (Don't Starve Together)
#
# --- Character Info ---
# Special Item(s):
# Starting Item(s): ×3
# Favorite Food:
# Code: "winona"
#
# --- Base Stats ---
# Health: 150
# Hunger: 150
# Sanity: 200
#
# Character Name: Warly (Don't Starve Together)
#
# --- Character Info ---
# Hunger Modifier: -1.2×
# Special Item(s):
# Starting Item(s): ×2
# Favorite Food: None
# Code: "warly"
#
# --- Base Stats ---
# Health: 150
# Hunger: 250
# Sanity: 200
#
# Character Name: Wortox (Don't Starve Together)
#
# --- Character Info ---
# Sanity Modifier: 0.5× vs. Monsters
# Special Item(s):
# Starting Item(s): ×6
# Favorite Food: and
# Code: "wortox"
#
# --- Base Stats ---
# Health: 200
# Hunger: 175
# Sanity: 150
#
# Character Name: Wormwood (Don't Starve Together)
#
# --- Character Info ---
# Special Item(s):
# Favorite Food:
# Code: "wormwood"
#
# --- Base Stats ---
# Health: 150
# Hunger: 150
# Sanity: 200
#
# Character Name: Wurt (Don't Starve Together)
#
# --- Character Info ---
# Speed Modifier: ×1 or ×1.3
# Special Item(s):
# Favorite Food: and
# Code: "wurt"
#
# --- Base Stats ---
# Health: 150 or 250
# Hunger: 200 or 250
# Sanity: 150 or 200
#
# Character Name: Walter (Don't Starve Together)
#
# --- Character Info ---
# Damage Modifier: +10 when attacked by Bee Mob
# Hunger Modifier: -0.5× when Sleeping
# Sanity Modifier: 0 in darkness, when being near monster, structures and/or wearing clothes, 1 when being effected by magic, +6/min when being near Trees, up to -12/min when health is not full
# Special Item(s):
# Starting Item(s): ×10
# Favorite Food:
# Code: "walter"
#
# --- Base Stats ---
# Health: 130
# Hunger: 110
# Sanity: 200
#
# Character Name: Wanda (Don't Starve Together)
#
# --- Character Info ---
# Special Item(s):
# Starting Item(s): , ×3
# Favorite Food:
# Code: "wanda"
#
# --- Base Stats ---
# Hunger: 175
# Sanity: 200
#
# Character Name: Wonkey (Don't Starve Together)
#
# --- Character Info ---
# Favorite Food:
# Code: "wonkey"
#
# --- Base Stats ---
# Health: 125
# Hunger: 175
# Sanity: 100
#
# All character data has been saved to 'characters_data.json'
